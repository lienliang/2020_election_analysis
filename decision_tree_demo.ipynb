# %%
import numpy as np
import pandas as pd
import sklearn
# %matplotlib inline

# %%
path = './data/election-context-2018.csv'
data = pd.read_csv(path)

# %%
data
# Out:
#         state      county   fips  trump16  clinton16  otherpres16  romney12  \
# 0     Alabama     Autauga   1001    18172       5936          865     17379
# 1     Alabama     Baldwin   1003    72883      18458         3874     66016
# 2     Alabama     Barbour   1005     5454       4871          144      5550
# 3     Alabama        Bibb   1007     6738       1874          207      6132
# 4     Alabama      Blount   1009    22859       2156          573     20757
# ...       ...         ...    ...      ...        ...          ...       ...
# 3109  Wyoming  Sweetwater  56037    12154       3231         1745     11428
# 3110  Wyoming       Teton  56039     3921       7314         1392      4858
# 3111  Wyoming       Uinta  56041     6154       1202         1114      6615
# 3112  Wyoming    Washakie  56043     2911        532          371      3014
# 3113  Wyoming      Weston  56045     3033        299          194      2821
#
#       obama12  otherpres12  demsen16  ...  age29andunder_pct  \
# 0        6363          190    6331.0  ...          40.037058
# 1       18424          898   19145.0  ...          35.474412
# 2        5912           47    4777.0  ...          37.664387
# 3        2202           86    2082.0  ...          37.329435
# 4        2970          279    2980.0  ...          37.240053
# ...       ...          ...       ...  ...                ...
# 3109     4774          693       NaN  ...          44.153352
# 3110     6213          393       NaN  ...          35.569995
# 3111     1628          296       NaN  ...          43.205858
# 3112      794          136       NaN  ...          34.774279
# 3113      422          116       NaN  ...          33.282230
#
#       age65andolder_pct  median_hh_inc  clf_unemploy_pct  lesshs_pct  \
# 0             13.978456        53099.0          5.591657   12.417046
# 1             18.714851        51365.0          6.286843    9.972418
# 2             16.528895        33956.0         12.824738   26.235928
# 3             14.885699        39776.0          7.146827   19.301587
# 4             17.192916        46212.0          5.953833   19.968585
# ...                 ...            ...               ...         ...
# 3109           9.417120        68233.0          5.072255    9.314606
# 3110          11.837510        75594.0          2.123447    4.633570
# 3111          10.678218        53323.0          6.390755   10.361224
# 3112          19.650341        46212.0          7.441860   12.577108
# 3113          18.355401        55640.0          3.610949    8.592392
#
#       lesscollege_pct  lesshs_whites_pct  lesscollege_whites_pct  rural_pct  \
# 0           75.407229          10.002112               74.065601  42.002162
# 1           70.452889           7.842227               68.405607  42.279099
# 2           87.132213          19.579752               81.364746  67.789635
# 3           88.000000          15.020490               87.471774  68.352607
# 4           86.950243          16.643368               86.163610  89.951502
# ...               ...                ...                     ...        ...
# 3109        78.628507           6.238463               76.606813  10.916313
# 3110        46.211584           1.526877               41.769504  46.430920
# 3111        81.793082           8.806312               81.080852  43.095937
# 3112        78.923920          10.299738               75.980688  35.954529
# 3113        81.193281           7.342144               81.141179  54.536626
#
#       ruralurban_cc
# 0               2.0
# 1               3.0
# 2               6.0
# 3               1.0
# 4               1.0
# ...             ...
# 3109            5.0
# 3110            7.0
# 3111            7.0
# 3112            7.0
# 3113            7.0
#
# [3114 rows x 39 columns]

# %% [markdown]
# # Add a new column here, value is 1 if Trump wins majority in that county, else 0

# %%
def winner_2016(row):
    return 1 if row['trump16'] > row['clinton16'] else 0

# %% [markdown]
# # Create new columns based on existing colunms,
# ### see https://stackoverflow.com/questions/26886653/pandas-create-new-column-based-on-values-from-other-columns-apply-a-function-o

# %%
data['winner_16'] = data.apply (lambda row: winner_2016(row), axis=1)

# %%
data = data.drop(['demgov16','repgov16','othergov16'], axis=1) # these columns are all N/A

# %%
data
# Out:
#         state      county   fips  trump16  clinton16  otherpres16  romney12  \
# 0     Alabama     Autauga   1001    18172       5936          865     17379
# 1     Alabama     Baldwin   1003    72883      18458         3874     66016
# 2     Alabama     Barbour   1005     5454       4871          144      5550
# 3     Alabama        Bibb   1007     6738       1874          207      6132
# 4     Alabama      Blount   1009    22859       2156          573     20757
# ...       ...         ...    ...      ...        ...          ...       ...
# 3109  Wyoming  Sweetwater  56037    12154       3231         1745     11428
# 3110  Wyoming       Teton  56039     3921       7314         1392      4858
# 3111  Wyoming       Uinta  56041     6154       1202         1114      6615
# 3112  Wyoming    Washakie  56043     2911        532          371      3014
# 3113  Wyoming      Weston  56045     3033        299          194      2821
#
#       obama12  otherpres12  demsen16  ...  age65andolder_pct  median_hh_inc  \
# 0        6363          190    6331.0  ...          13.978456        53099.0
# 1       18424          898   19145.0  ...          18.714851        51365.0
# 2        5912           47    4777.0  ...          16.528895        33956.0
# 3        2202           86    2082.0  ...          14.885699        39776.0
# 4        2970          279    2980.0  ...          17.192916        46212.0
# ...       ...          ...       ...  ...                ...            ...
# 3109     4774          693       NaN  ...           9.417120        68233.0
# 3110     6213          393       NaN  ...          11.837510        75594.0
# 3111     1628          296       NaN  ...          10.678218        53323.0
# 3112      794          136       NaN  ...          19.650341        46212.0
# 3113      422          116       NaN  ...          18.355401        55640.0
#
#       clf_unemploy_pct  lesshs_pct  lesscollege_pct  lesshs_whites_pct  \
# 0             5.591657   12.417046        75.407229          10.002112
# 1             6.286843    9.972418        70.452889           7.842227
# 2            12.824738   26.235928        87.132213          19.579752
# 3             7.146827   19.301587        88.000000          15.020490
# 4             5.953833   19.968585        86.950243          16.643368
# ...                ...         ...              ...                ...
# 3109          5.072255    9.314606        78.628507           6.238463
# 3110          2.123447    4.633570        46.211584           1.526877
# 3111          6.390755   10.361224        81.793082           8.806312
# 3112          7.441860   12.577108        78.923920          10.299738
# 3113          3.610949    8.592392        81.193281           7.342144
#
#       lesscollege_whites_pct  rural_pct  ruralurban_cc  winner_16
# 0                  74.065601  42.002162            2.0          1
# 1                  68.405607  42.279099            3.0          1
# 2                  81.364746  67.789635            6.0          1
# 3                  87.471774  68.352607            1.0          1
# 4                  86.163610  89.951502            1.0          1
# ...                      ...        ...            ...        ...
# 3109               76.606813  10.916313            5.0          1
# 3110               41.769504  46.430920            7.0          0
# 3111               81.080852  43.095937            7.0          1
# 3112               75.980688  35.954529            7.0          1
# 3113               81.141179  54.536626            7.0          1
#
# [3114 rows x 37 columns]

# %% [markdown]
# # Note: There are a number of counties not holding elections in 2018, if we want to have a model to prediction senator, house and president all at once, we will need to drop some more rows.

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()

# %%
training_set = data.iloc[:, 20:] # features starting at index 20 after dropping 3 N/A columns

# %%
training_set = training_set.dropna()

# %%
x = training_set.iloc[:, :-1]
y = training_set.iloc[:, -1:]

# %%
clf = clf.fit(x, y)

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("election")
# Out:
# 'election.pdf'

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=colunms,  
                     class_names=['trump', 'clinton'],  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph.render("election_tree") #create the image below as a pdf file under this folder
graph
